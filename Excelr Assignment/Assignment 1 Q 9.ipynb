# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars_a = pd.read_csv(r"C:\Users\Karan\Downloads\Q9_a (1).csv")
cars_a
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
cars_b = pd.read_csv(r"C:\Users\Karan\Downloads\Q9_b (1).csv")
cars_b
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
cars_a.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
cars_a.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
cars_b.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
cars_b.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
cars_a.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Index'}>,
#         <AxesSubplot:title={'center':'speed'}>],
#        [<AxesSubplot:title={'center':'dist'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
cars_b.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'SP'}>],
#        [<AxesSubplot:title={'center':'WT'}>, <AxesSubplot:>]],
#       dtype=object)
